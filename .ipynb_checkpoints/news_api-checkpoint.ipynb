# %%
import requests
import json
import re
import pandas as pd
import sklearn
import os
import nltk
import string
import newspaper

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from newspaper import Article

# %%
########## BUILD CSV WITH LABELS, DESCRIPTION, AND CONTENT ##########

api_key = "4fe8b78ffdb64b0fb8dbfda6a3ba99f6"
url = "https://newsapi.org/v2/everything"

params_paul = {"q": "Beatles",
               "language": "en",
               "sortBy": "publishedAt",
               "apiKey": api_key,
               "source": "rollingstone.com"}

params_john = {"q": "John Lennon",
               "language": "en",
               "sortBy": "publishedAt",
               "apiKey": api_key}

response_paul = requests.get(url, params=params_paul)
response_john = requests.get(url, params=params_john)

if response_paul.status_code == 200:
    json_txt_paul = response_paul.json()
    paul_articles = json_txt_paul.get("articles", [])

else:
    print(f"Error: {response_paul.status_code}, {response_paul.text}")

if response_john.status_code == 200:
    json_txt_john = response_john.json()
    john_articles = json_txt_john.get("articles", [])

else:
    print(f"Error: {response_john.status_code}, {response_john.text}")

# # Create new file that will be written later. 
# filename = "paul_john_raw.csv"

# # Open file 
# my_file = open(filename,"w")

# # Write column names in first row
# write_this = "Label,Description, Content\n"
# my_file.write(write_this)
# my_file.close()

# # Open file for appending to
# my_file = open(filename, "a")
# for item in paul_articles:
#     label = 'paul'
#     headline = item["description"]
    
#     if(headline != None):
#         headline = re.sub(r'[,.;@#?!&$\-\']+', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(' +', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(r'\"', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(r'[^a-zA-Z]', " ", headline, flags = re.VERBOSE)
#         headline = headline.replace(',', '')
#         headline = ' '.join(headline.split())
#         headline = re.sub("\n|\r", "", headline)

#     # # Get article content
#     # url = item['url']
#     # article = Article(url)
#     # article.download()
#     # article.parse()

    
#     write_this = str(label) + "," + str(headline) + str(article) + "\n"
#     my_file.write(write_this)
    
# my_file.close()

# # Open file for appending to
# my_file = open(filename, "a")
# for item in john_articles:
#     label = 'john'
#     headline = item["description"]
#     if(headline != None):
#         headline = re.sub(r'[,.;@#?!&$\-\']+', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(' +', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(r'\"', ' ', headline, flags = re.IGNORECASE)
#         headline = re.sub(r'[^a-zA-Z]', " ", headline, flags = re.VERBOSE)
#         headline = headline.replace(',', '')
#         headline = ' '.join(headline.split())
#         headline = re.sub("\n|\r", "", headline)

#     write_this = str(label) + "," + str(headline) + "\n"
#     my_file.write(write_this)
    
# my_file.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[28], line 38
#      35 filename = "paul_john_raw.csv"
#      37 # Open file
# ---> 38 my_file = open(filename,"w")
#      40 # Write column names in first row
#      41 write_this = "Label,Description, Content\n"
#
# File ~\New folder\lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'paul_john_raw.csv'
